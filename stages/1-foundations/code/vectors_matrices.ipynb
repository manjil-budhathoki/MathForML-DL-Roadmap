# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Lecture 1 Implementation

# %%
x = np.array([1,2,3])
y = np.array([2,3,4])

# %%
# vector addition
U = x + y
print(f"Addition of vector X and Y: {U}")
# Out:
# Addition of vector X and Y: [3 5 7]

# %%
# Scaling the vector or multipling
V = x * y
print(f"Multipication of Vector X and Y: {V}")
# Out:
# Multipication of Vector X and Y: [ 2  6 12]
